# %% [markdown]
# # Potencial Talents

# %% [markdown]
# This apparently requires a unsupervised ranking

# %% [markdown]
# ## Importing Dependencies

# %%
from sklearn.model_selection import train_test_split
from sklearn.metrics import accuracy_score, confusion_matrix, ConfusionMatrixDisplay, classification_report, average_precision_score
from sklearn.preprocessing import StandardScaler, OneHotEncoder
from sklearn.model_selection import cross_val_score
from sklearn.feature_extraction.text import TfidfVectorizer
from sklearn.metrics.pairwise import cosine_similarity
from sklearn.compose import make_column_transformer

import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import numpy as np

print('Modules Imported')
# Out:
# Modules Imported

# %% [markdown]
# ## Import Data

# %%
data_path = 'potential-talents.xlsx'

# %%
data = pd.read_excel(data_path)

data
# Out:
#       id                                          job_title  \
# 0      1  2019 C.T. Bauer College of Business Graduate (...
# 1      2  Native English Teacher at EPIK (English Progra...
# 2      3              Aspiring Human Resources Professional
# 3      4             People Development Coordinator at Ryan
# 4      5    Advisory Board Member at Celal Bayar University
# ..   ...                                                ...
# 99   100  Aspiring Human Resources Manager | Graduating ...
# 100  101              Human Resources Generalist at Loparex
# 101  102   Business Intelligence and Analytics at Travelers
# 102  103                     Always set them up for Success
# 103  104   Director Of Administration at Excellence Logging
#
#                                 location connection  fit
# 0                         Houston, Texas         85  NaN
# 1                                 Kanada      500+   NaN
# 2    Raleigh-Durham, North Carolina Area         44  NaN
# 3                          Denton, Texas      500+   NaN
# 4                         İzmir, Türkiye      500+   NaN
# ..                                   ...        ...  ...
# 99              Cape Girardeau, Missouri        103  NaN
# 100  Raleigh-Durham, North Carolina Area      500+   NaN
# 101           Greater New York City Area         49  NaN
# 102             Greater Los Angeles Area      500+   NaN
# 103                          Katy, Texas      500+   NaN
#
# [104 rows x 5 columns]

# %% [markdown]
# ## Exploring Dataset

# %% [markdown]
# **X:**
#
# - `id`: unique identifier for candidate (numeric)
# - `job_title`: job title for candidate (text)
# - `location`: geographical location for candidate (text)
# - `connections`: number of connections candidate has, 500+ means over 500 (text)
#
# **Y:**
#
# - `fit`: how fit the candidate is for the role? (numeric, probability between 0-1)

# %%
keywords = ['Aspiring human resources','seeking human resources']

# %% [markdown]
# The words that will be used for semantic search

# %%
job_titles = data['job_title']

job_titles
# Out:
# 0      2019 C.T. Bauer College of Business Graduate (...
# 1      Native English Teacher at EPIK (English Progra...
# 2                  Aspiring Human Resources Professional
# 3                 People Development Coordinator at Ryan
# 4        Advisory Board Member at Celal Bayar University
#                              ...
# 99     Aspiring Human Resources Manager | Graduating ...
# 100                Human Resources Generalist at Loparex
# 101     Business Intelligence and Analytics at Travelers
# 102                       Always set them up for Success
# 103     Director Of Administration at Excellence Logging
# Name: job_title, Length: 104, dtype: object

# %% [markdown]
# Fetching job titles from the dataframe

# %%
vectorizer = TfidfVectorizer()

# Creating matrix based on the vectorization of the job titles
job_titles_matrix = vectorizer.fit_transform(job_titles)

# Creating matrix based on the vectorization of the keywords
keywords_matrix = vectorizer.transform(keywords)

# %%
# Geting a matrix with the similarity score from comparing the job titles with the keywords
resulting_matrix = cosine_similarity(job_titles_matrix, keywords_matrix)

# Getting the sum score of all tokens from each candidate
#resulting_matrix = resulting_matrix.sum(axis=1)

# Getting the mean score of all tokens from each candidate
#resulting_matrix = resulting_matrix.mean(axis=1)

# Getting the max score of all tokens from each candidate
resulting_matrix = resulting_matrix.max(axis=1)

# %%
# Adding the score data to the fit column
data = data.assign(fit=resulting_matrix)

data
# Out:
#       id                                          job_title  \
# 0      1  2019 C.T. Bauer College of Business Graduate (...
# 1      2  Native English Teacher at EPIK (English Progra...
# 2      3              Aspiring Human Resources Professional
# 3      4             People Development Coordinator at Ryan
# 4      5    Advisory Board Member at Celal Bayar University
# ..   ...                                                ...
# 99   100  Aspiring Human Resources Manager | Graduating ...
# 100  101              Human Resources Generalist at Loparex
# 101  102   Business Intelligence and Analytics at Travelers
# 102  103                     Always set them up for Success
# 103  104   Director Of Administration at Excellence Logging
#
#                                 location connection       fit
# 0                         Houston, Texas         85  0.265312
# 1                                 Kanada      500+   0.000000
# 2    Raleigh-Durham, North Carolina Area         44  0.753591
# 3                          Denton, Texas      500+   0.000000
# 4                         İzmir, Türkiye      500+   0.000000
# ..                                   ...        ...       ...
# 99              Cape Girardeau, Missouri        103  0.303599
# 100  Raleigh-Durham, North Carolina Area      500+   0.242570
# 101           Greater New York City Area         49  0.000000
# 102             Greater Los Angeles Area      500+   0.000000
# 103                          Katy, Texas      500+   0.000000
#
# [104 rows x 5 columns]

# %%
data.head()
# Out:
#    id                                          job_title  \
# 0   1  2019 C.T. Bauer College of Business Graduate (...
# 1   2  Native English Teacher at EPIK (English Progra...
# 2   3              Aspiring Human Resources Professional
# 3   4             People Development Coordinator at Ryan
# 4   5    Advisory Board Member at Celal Bayar University
#
#                               location connection       fit
# 0                       Houston, Texas         85  0.265312
# 1                               Kanada      500+   0.000000
# 2  Raleigh-Durham, North Carolina Area         44  0.753591
# 3                        Denton, Texas      500+   0.000000
# 4                       İzmir, Türkiye      500+   0.000000

# %%
sorted_fit_data = data.sort_values(by=['fit'], ascending=False)

# %%
sorted_fit_data.head(10)
# Out:
#     id                              job_title  \
# 2    3  Aspiring Human Resources Professional
# 32  33  Aspiring Human Resources Professional
# 16  17  Aspiring Human Resources Professional
# 20  21  Aspiring Human Resources Professional
# 57  58  Aspiring Human Resources Professional
# 96  97  Aspiring Human Resources Professional
# 45  46  Aspiring Human Resources Professional
# 23  24    Aspiring Human Resources Specialist
# 59  60    Aspiring Human Resources Specialist
# 5    6    Aspiring Human Resources Specialist
#
#                                location connection       fit
# 2   Raleigh-Durham, North Carolina Area         44  0.753591
# 32  Raleigh-Durham, North Carolina Area         44  0.753591
# 16  Raleigh-Durham, North Carolina Area         44  0.753591
# 20  Raleigh-Durham, North Carolina Area         44  0.753591
# 57  Raleigh-Durham, North Carolina Area         44  0.753591
# 96                 Kokomo, Indiana Area         71  0.753591
# 45  Raleigh-Durham, North Carolina Area         44  0.753591
# 23           Greater New York City Area          1  0.695679
# 59           Greater New York City Area          1  0.695679
# 5            Greater New York City Area          1  0.695679

# %% [markdown]
# ## Transforming Features

# %%
selected_features = sorted_fit_data[['location','connection','fit']].copy()

# %%
selected_features['connection'] = selected_features['connection'].map(lambda x: 500 if x == "500+ " else pd.to_numeric(x))

# %%
selected_features.head(10)
# Out:
#                                location  connection       fit
# 2   Raleigh-Durham, North Carolina Area          44  0.753591
# 32  Raleigh-Durham, North Carolina Area          44  0.753591
# 16  Raleigh-Durham, North Carolina Area          44  0.753591
# 20  Raleigh-Durham, North Carolina Area          44  0.753591
# 57  Raleigh-Durham, North Carolina Area          44  0.753591
# 96                 Kokomo, Indiana Area          71  0.753591
# 45  Raleigh-Durham, North Carolina Area          44  0.753591
# 23           Greater New York City Area           1  0.695679
# 59           Greater New York City Area           1  0.695679
# 5            Greater New York City Area           1  0.695679

# %%
ohe = OneHotEncoder(sparse_output=False).set_output(transform='pandas')

ohe_transformation = ohe.fit_transform(selected_features[['location']])

selected_features = pd.concat([selected_features, ohe_transformation], axis=1).drop(columns='location')

# %%
preprocessor = make_column_transformer(
    (StandardScaler(), ['connection', 'fit']),          
    remainder='passthrough'                              
)

X = preprocessor.fit_transform(selected_features)

# %%
# The 7th candidate
role_idx = 6  
role_vector = X[role_idx].reshape(1, -1)

selected_features.iloc[role_idx]
# Out:
# connection                                      44.0
# fit                                              1.0
# location_Amerika Birleşik Devletleri             0.0
# location_Atlanta, Georgia                        0.0
# location_Austin, Texas Area                      0.0
# location_Baltimore, Maryland                     0.0
# location_Baton Rouge, Louisiana Area             0.0
# location_Bridgewater, Massachusetts              0.0
# location_Cape Girardeau, Missouri                0.0
# location_Chattanooga, Tennessee Area             0.0
# location_Chicago, Illinois                       0.0
# location_Dallas/Fort Worth Area                  0.0
# location_Denton, Texas                           0.0
# location_Gaithersburg, Maryland                  0.0
# location_Greater Atlanta Area                    0.0
# location_Greater Boston Area                     0.0
# location_Greater Chicago Area                    0.0
# location_Greater Grand Rapids, Michigan Area     0.0
# location_Greater Los Angeles Area                0.0
# location_Greater New York City Area              0.0
# location_Greater Philadelphia Area               0.0
# location_Highland, California                    0.0
# location_Houston, Texas                          0.0
# location_Houston, Texas Area                     0.0
# location_Jackson, Mississippi Area               0.0
# location_Kanada                                  0.0
# location_Katy, Texas                             0.0
# location_Kokomo, Indiana Area                    0.0
# location_Lafayette, Indiana                      0.0
# location_Lake Forest, California                 0.0
# location_Las Vegas, Nevada Area                  0.0
# location_Long Beach, California                  0.0
# location_Los Angeles, California                 0.0
# location_Milpitas, California                    0.0
# location_Monroe, Louisiana Area                  0.0
# location_Myrtle Beach, South Carolina Area       0.0
# location_New York, New York                      0.0
# location_Raleigh-Durham, North Carolina Area     1.0
# location_San Francisco Bay Area                  0.0
# location_San Jose, California                    0.0
# location_Torrance, California                    0.0
# location_Virginia Beach, Virginia                0.0
# location_İzmir, Türkiye                          0.0
# Name: 45, dtype: float64

# %%
selected_features['fit'] = cosine_similarity(X, role_vector).flatten()

# %%
selected_features = selected_features.sort_values('fit', ascending=False)

# %%
selected_features.head(10)
# Out:
#     connection       fit  location_Amerika Birleşik Devletleri  \
# 2           44  1.000000                                   0.0
# 32          44  1.000000                                   0.0
# 16          44  1.000000                                   0.0
# 20          44  1.000000                                   0.0
# 57          44  1.000000                                   0.0
# 45          44  1.000000                                   0.0
# 96          71  0.834543                                   0.0
# 23           1  0.825223                                   0.0
# 59           1  0.825223                                   0.0
# 5            1  0.825223                                   0.0
#
#     location_Atlanta, Georgia  location_Austin, Texas Area  \
# 2                         0.0                          0.0
# 32                        0.0                          0.0
# 16                        0.0                          0.0
# 20                        0.0                          0.0
# 57                        0.0                          0.0
# 45                        0.0                          0.0
# 96                        0.0                          0.0
# 23                        0.0                          0.0
# 59                        0.0                          0.0
# 5                         0.0                          0.0
#
#     location_Baltimore, Maryland  location_Baton Rouge, Louisiana Area  \
# 2                            0.0                                   0.0
# 32                           0.0                                   0.0
# 16                           0.0                                   0.0
# 20                           0.0                                   0.0
# 57                           0.0                                   0.0
# 45                           0.0                                   0.0
# 96                           0.0                                   0.0
# 23                           0.0                                   0.0
# 59                           0.0                                   0.0
# 5                            0.0                                   0.0
#
#     location_Bridgewater, Massachusetts  location_Cape Girardeau, Missouri  \
# 2                                   0.0                                0.0
# 32                                  0.0                                0.0
# 16                                  0.0                                0.0
# 20                                  0.0                                0.0
# 57                                  0.0                                0.0
# 45                                  0.0                                0.0
# 96                                  0.0                                0.0
# 23                                  0.0                                0.0
# 59                                  0.0                                0.0
# 5                                   0.0                                0.0
#
#     location_Chattanooga, Tennessee Area  ...  location_Milpitas, California  \
# 2                                    0.0  ...                            0.0
# 32                                   0.0  ...                            0.0
# 16                                   0.0  ...                            0.0
# 20                                   0.0  ...                            0.0
# 57                                   0.0  ...                            0.0
# 45                                   0.0  ...                            0.0
# 96                                   0.0  ...                            0.0
# 23                                   0.0  ...                            0.0
# 59                                   0.0  ...                            0.0
# 5                                    0.0  ...                            0.0
#
#     location_Monroe, Louisiana Area  \
# 2                               0.0
# 32                              0.0
# 16                              0.0
# 20                              0.0
# 57                              0.0
# 45                              0.0
# 96                              0.0
# 23                              0.0
# 59                              0.0
# 5                               0.0
#
#     location_Myrtle Beach, South Carolina Area  location_New York, New York  \
# 2                                          0.0                          0.0
# 32                                         0.0                          0.0
# 16                                         0.0                          0.0
# 20                                         0.0                          0.0
# 57                                         0.0                          0.0
# 45                                         0.0                          0.0
# 96                                         0.0                          0.0
# 23                                         0.0                          0.0
# 59                                         0.0                          0.0
# 5                                          0.0                          0.0
#
#     location_Raleigh-Durham, North Carolina Area  \
# 2                                            1.0
# 32                                           1.0
# 16                                           1.0
# 20                                           1.0
# 57                                           1.0
# 45                                           1.0
# 96                                           0.0
# 23                                           0.0
# 59                                           0.0
# 5                                            0.0
#
#     location_San Francisco Bay Area  location_San Jose, California  \
# 2                               0.0                            0.0
# 32                              0.0                            0.0
# 16                              0.0                            0.0
# 20                              0.0                            0.0
# 57                              0.0                            0.0
# 45                              0.0                            0.0
# 96                              0.0                            0.0
# 23                              0.0                            0.0
# 59                              0.0                            0.0
# 5                               0.0                            0.0
#
#     location_Torrance, California  location_Virginia Beach, Virginia  \
# 2                             0.0                                0.0
# 32                            0.0                                0.0
# 16                            0.0                                0.0
# 20                            0.0                                0.0
# 57                            0.0                                0.0
# 45                            0.0                                0.0
# 96                            0.0                                0.0
# 23                            0.0                                0.0
# 59                            0.0                                0.0
# 5                             0.0                                0.0
#
#     location_İzmir, Türkiye
# 2                       0.0
# 32                      0.0
# 16                      0.0
# 20                      0.0
# 57                      0.0
# 45                      0.0
# 96                      0.0
# 23                      0.0
# 59                      0.0
# 5                       0.0
#
# [10 rows x 43 columns]
