# %% [markdown]
# # Potencial Talents

# %% [markdown]
# This apparently requires a unsupervised ranking

# %% [markdown]
# ## Importing Dependencies

# %%
from sklearn.model_selection import train_test_split
from sklearn.metrics import accuracy_score, confusion_matrix, ConfusionMatrixDisplay, classification_report, average_precision_score
from sklearn.preprocessing import StandardScaler, OneHotEncoder
from sklearn.model_selection import cross_val_score
from sklearn.feature_extraction.text import TfidfVectorizer
from sklearn.metrics.pairwise import cosine_similarity

import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import numpy as np

print('Modules Imported')
# Out:
# Modules Imported

# %% [markdown]
# ## Import Data

# %%
data_path = 'potential-talents.xlsx'

# %%
data = pd.read_excel(data_path)

data
# Out:
#       id                                          job_title  \
# 0      1  2019 C.T. Bauer College of Business Graduate (...
# 1      2  Native English Teacher at EPIK (English Progra...
# 2      3              Aspiring Human Resources Professional
# 3      4             People Development Coordinator at Ryan
# 4      5    Advisory Board Member at Celal Bayar University
# ..   ...                                                ...
# 99   100  Aspiring Human Resources Manager | Graduating ...
# 100  101              Human Resources Generalist at Loparex
# 101  102   Business Intelligence and Analytics at Travelers
# 102  103                     Always set them up for Success
# 103  104   Director Of Administration at Excellence Logging
#
#                                 location connection  fit
# 0                         Houston, Texas         85  NaN
# 1                                 Kanada      500+   NaN
# 2    Raleigh-Durham, North Carolina Area         44  NaN
# 3                          Denton, Texas      500+   NaN
# 4                         İzmir, Türkiye      500+   NaN
# ..                                   ...        ...  ...
# 99              Cape Girardeau, Missouri        103  NaN
# 100  Raleigh-Durham, North Carolina Area      500+   NaN
# 101           Greater New York City Area         49  NaN
# 102             Greater Los Angeles Area      500+   NaN
# 103                          Katy, Texas      500+   NaN
#
# [104 rows x 5 columns]

# %% [markdown]
# ## Exploring Dataset

# %% [markdown]
# **X:**
#
# - `id`: unique identifier for candidate (numeric)
# - `job_title`: job title for candidate (text)
# - `location`: geographical location for candidate (text)
# - `connections`: number of connections candidate has, 500+ means over 500 (text)
#
# **Y:**
#
# - `fit`: how fit the candidate is for the role? (numeric, probability between 0-1)

# %%
keywords = ['Aspiring human resources','seeking human resources']

# %% [markdown]
# The words that will be used for semantic search

# %%
job_titles = data['job_title']

job_titles
# Out:
# 0      2019 C.T. Bauer College of Business Graduate (...
# 1      Native English Teacher at EPIK (English Progra...
# 2                  Aspiring Human Resources Professional
# 3                 People Development Coordinator at Ryan
# 4        Advisory Board Member at Celal Bayar University
#                              ...
# 99     Aspiring Human Resources Manager | Graduating ...
# 100                Human Resources Generalist at Loparex
# 101     Business Intelligence and Analytics at Travelers
# 102                       Always set them up for Success
# 103     Director Of Administration at Excellence Logging
# Name: job_title, Length: 104, dtype: object

# %% [markdown]
# Fetching job titles from the dataframe

# %%
vectorizer = TfidfVectorizer()

# Creating matrix based on the vectorization of the job titles
job_titles_matrix = vectorizer.fit_transform(job_titles)

# Creating matrix based on the vectorization of the keywords
keywords_matrix = vectorizer.transform(keywords)

# %%
# Geting a matrix with the similarity score from comparing the job titles with the keywords
resulting_matrix = cosine_similarity(job_titles_matrix, keywords_matrix)

# Getting the sum score of all tokens from each candidate
#resulting_matrix = resulting_matrix.sum(axis=1)

# Getting the mean score of all tokens from each candidate
#resulting_matrix = resulting_matrix.mean(axis=1)

# Getting the max score of all tokens from each candidate
resulting_matrix = resulting_matrix.max(axis=1)

resulting_matrix
# Out:
# array([0.26531227, 0.        , 0.753591  , 0.        , 0.        ,
#        0.69567872, 0.40060921, 0.        , 0.40060921, 0.46581385,
#        0.        , 0.        , 0.18946052, 0.26531227, 0.26531227,
#        0.        , 0.753591  , 0.        , 0.26531227, 0.        ,
#        0.753591  , 0.        , 0.        , 0.69567872, 0.40060921,
#        0.        , 0.42408409, 0.66493323, 0.42408409, 0.66493323,
#        0.26531227, 0.        , 0.753591  , 0.        , 0.        ,
#        0.69567872, 0.40060921, 0.        , 0.40060921, 0.46581385,
#        0.        , 0.        , 0.18946052, 0.26531227, 0.        ,
#        0.753591  , 0.        , 0.        , 0.69567872, 0.40060921,
#        0.        , 0.40060921, 0.46581385, 0.        , 0.        ,
#        0.18946052, 0.26531227, 0.753591  , 0.        , 0.69567872,
#        0.        , 0.46581385, 0.        , 0.        , 0.18946052,
#        0.33596153, 0.19758021, 0.24007198, 0.13984911, 0.25320642,
#        0.1920007 , 0.35981638, 0.57364362, 0.46015863, 0.23711439,
#        0.18781711, 0.10824288, 0.24257007, 0.29767933, 0.        ,
#        0.15165424, 0.26172354, 0.        , 0.12734654, 0.        ,
#        0.        , 0.        , 0.25753129, 0.21863268, 0.        ,
#        0.        , 0.1643098 , 0.        , 0.31665961, 0.        ,
#        0.        , 0.753591  , 0.        , 0.64485098, 0.30359897,
#        0.24257007, 0.        , 0.        , 0.        ])

# %%
# Adding the score data to the fit column
data = data.assign(fit=resulting_matrix)

data
# Out:
#       id                                          job_title  \
# 0      1  2019 C.T. Bauer College of Business Graduate (...
# 1      2  Native English Teacher at EPIK (English Progra...
# 2      3              Aspiring Human Resources Professional
# 3      4             People Development Coordinator at Ryan
# 4      5    Advisory Board Member at Celal Bayar University
# ..   ...                                                ...
# 99   100  Aspiring Human Resources Manager | Graduating ...
# 100  101              Human Resources Generalist at Loparex
# 101  102   Business Intelligence and Analytics at Travelers
# 102  103                     Always set them up for Success
# 103  104   Director Of Administration at Excellence Logging
#
#                                 location connection       fit
# 0                         Houston, Texas         85  0.265312
# 1                                 Kanada      500+   0.000000
# 2    Raleigh-Durham, North Carolina Area         44  0.753591
# 3                          Denton, Texas      500+   0.000000
# 4                         İzmir, Türkiye      500+   0.000000
# ..                                   ...        ...       ...
# 99              Cape Girardeau, Missouri        103  0.303599
# 100  Raleigh-Durham, North Carolina Area      500+   0.242570
# 101           Greater New York City Area         49  0.000000
# 102             Greater Los Angeles Area      500+   0.000000
# 103                          Katy, Texas      500+   0.000000
#
# [104 rows x 5 columns]

# %%
data.head()
# Out:
#    id                                          job_title  \
# 0   1  2019 C.T. Bauer College of Business Graduate (...
# 1   2  Native English Teacher at EPIK (English Progra...
# 2   3              Aspiring Human Resources Professional
# 3   4             People Development Coordinator at Ryan
# 4   5    Advisory Board Member at Celal Bayar University
#
#                               location connection       fit
# 0                       Houston, Texas         85  0.265312
# 1                               Kanada      500+   0.000000
# 2  Raleigh-Durham, North Carolina Area         44  0.753591
# 3                        Denton, Texas      500+   0.000000
# 4                       İzmir, Türkiye      500+   0.000000

# %%
sorted_fit_data = data.sort_values(by=['fit'], ascending=False)

# %%
sorted_fit_data.head(50)
# Out:
#       id                                          job_title  \
# 2      3              Aspiring Human Resources Professional
# 32    33              Aspiring Human Resources Professional
# 16    17              Aspiring Human Resources Professional
# 20    21              Aspiring Human Resources Professional
# 57    58              Aspiring Human Resources Professional
# 96    97              Aspiring Human Resources Professional
# 45    46              Aspiring Human Resources Professional
# 23    24                Aspiring Human Resources Specialist
# 59    60                Aspiring Human Resources Specialist
# 5      6                Aspiring Human Resources Specialist
# 35    36                Aspiring Human Resources Specialist
# 48    49                Aspiring Human Resources Specialist
# 29    30              Seeking Human Resources Opportunities
# 27    28              Seeking Human Resources Opportunities
# 98    99                   Seeking Human Resources Position
# 72    73  Aspiring Human Resources Manager, seeking inte...
# 52    53  Seeking Human Resources HRIS and Generalist Po...
# 9     10  Seeking Human Resources HRIS and Generalist Po...
# 39    40  Seeking Human Resources HRIS and Generalist Po...
# 61    62  Seeking Human Resources HRIS and Generalist Po...
# 73    74                       Human Resources Professional
# 28    29  Aspiring Human Resources Management student se...
# 26    27  Aspiring Human Resources Management student se...
# 6      7  Student at Humber College and Aspiring Human R...
# 36    37  Student at Humber College and Aspiring Human R...
# 38    39  Student at Humber College and Aspiring Human R...
# 8      9  Student at Humber College and Aspiring Human R...
# 24    25  Student at Humber College and Aspiring Human R...
# 51    52  Student at Humber College and Aspiring Human R...
# 49    50  Student at Humber College and Aspiring Human R...
# 71    72  Business Management Major and Aspiring Human R...
# 65    66  Experienced Retail Manager and aspiring Human ...
# 93    94  Seeking Human  Resources Opportunities. Open t...
# 99   100  Aspiring Human Resources Manager | Graduating ...
# 78    79  Liberal Arts Major. Aspiring Human Resources A...
# 13    14  2019 C.T. Bauer College of Business Graduate (...
# 0      1  2019 C.T. Bauer College of Business Graduate (...
#